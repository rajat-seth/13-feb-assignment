# %% [markdown]
# Q1)

# %% [markdown]
# Exception class is used to create attributes that are not part of original exceptoion class in a custom exception.

# %% [markdown]
# Q2)

# %%
import inspect as ipt
def tree_class(cls,ind=0):
        
        print('_'*ind,cls.__name__)
        
        for K in cls.__subclasses__():
            tree_class(K,ind+3)
print("The Hierarchy for inbuilt exception is:")
            
ipt.getclasstree(ipt.getmro(BaseException))            
tree_class(BaseException)
# Out:
# The Hierarchy for inbuilt exception is:
#  BaseException
# ___ Exception
# ______ TypeError
# _________ FloatOperation
# _________ MultipartConversionError
# ______ StopAsyncIteration
# ______ StopIteration
# ______ ImportError
# _________ ModuleNotFoundError
# _________ ZipImportError
# ______ OSError
# _________ ConnectionError
# ____________ BrokenPipeError
# ____________ ConnectionAbortedError
# ____________ ConnectionRefusedError
# ____________ ConnectionResetError
# _______________ RemoteDisconnected
# _________ BlockingIOError
# _________ ChildProcessError
# _________ FileExistsError
# _________ FileNotFoundError
# _________ IsADirectoryError
# _________ NotADirectoryError
# _________ InterruptedError
# ____________ InterruptedSystemCall
# _________ PermissionError
# _________ ProcessLookupError
# _________ TimeoutError
# _________ UnsupportedOperation
# _________ itimer_error
# _________ herror
# _________ gaierror
# _________ SSLError
# ____________ SSLCertVerificationError
# ...

# %% [markdown]
# Q3)

# %% [markdown]
# Error Which are defined in arithmetic error class are Value error,ZeroDivisionError etc.

# %%
#Example 1:
a=6/0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[1], line 2
#       1 #Example 1:
# ----> 2 a=6/0
#
# ZeroDivisionError: division by zero

# %%
#example 2
import math
math.sqrt(-10)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 3
#       1 #example 2
#       2 import math
# ----> 3 math.sqrt(-10)
#
# ValueError: math domain error

# %% [markdown]
# Q4)

# %% [markdown]
# LookupError class is used to handle keyerror and indexerror.

# %%
x=[1,2,3,4,5]
try:
    print(x[10])
except LookupError as e:
    print(f"{e},{e.__class__}")
# Out:
# list index out of range,<class 'IndexError'>

# %%
a={"name":"rajat","age":"21"}
try:
    a["address"]
except LookupError as e:
    print(f"{e},{e.__class__}")
# Out:
# 'address',<class 'KeyError'>

# %% [markdown]
# Q5)

# %% [markdown]
# ImportError occurs when there is no such inbuilt python function that we basically try to import.

# %% [markdown]
# ModuleNotFound error occurs when one try to import the module that is not installed in your computer.

# %% [markdown]
# Q6)

# %% [markdown]
# Some best praactices are:
# #Logging must be used
# #Always avoid to write multiple exception handling.
# #Prepare a proper documentation
# #Clean up all the resources.
# #Use always a specfic excpetion.
